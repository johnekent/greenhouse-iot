# %%
import pandas as pd

# %%
df = pd.read_csv("c:\\temp\\Book1.csv")
df
# Out:
#      Unnamed: 0  RALSTHNG
# 0      1. abide       NaN
# 1      2. afire       NaN
# 2      3. agile       NaN
# 3      4. aging       NaN
# 4      5. alibi       NaN
# ..          ...       ...
# 261  262. whisk       NaN
# 262  263. white       NaN
# 263  264. wring       NaN
# 264  265. wrist       NaN
# 265  266. write       NaN
#
# [266 rows x 2 columns]

# %%
import re
def find_match(str):
    match = re.search('[ralsthng]', str)
    if match:
        return True
    else:
        return False

# %%
find_match('apple')
# Out:
# <re.Match object; span=(0, 1), match='a'>
# True

# %%
find_match('XXIIXX')
# Out:
# False

# %%
df['match'] = df['Unnamed: 0'].apply(find_match)
# Out:
# <re.Match object; span=(3, 4), match='a'>
# <re.Match object; span=(3, 4), match='a'>
# <re.Match object; span=(3, 4), match='a'>
# <re.Match object; span=(3, 4), match='a'>
# <re.Match object; span=(3, 4), match='a'>
# <re.Match object; span=(3, 4), match='a'>
# <re.Match object; span=(3, 4), match='a'>
# <re.Match object; span=(3, 4), match='a'>
# <re.Match object; span=(3, 4), match='a'>
# <re.Match object; span=(4, 5), match='a'>
# <re.Match object; span=(4, 5), match='a'>
# <re.Match object; span=(4, 5), match='a'>
# <re.Match object; span=(4, 5), match='a'>
# <re.Match object; span=(4, 5), match='a'>
# <re.Match object; span=(4, 5), match='a'>
# <re.Match object; span=(4, 5), match='a'>
# <re.Match object; span=(4, 5), match='a'>
# <re.Match object; span=(4, 5), match='a'>
# <re.Match object; span=(4, 5), match='a'>
# <re.Match object; span=(7, 8), match='n'>
# <re.Match object; span=(5, 6), match='l'>
# <re.Match object; span=(5, 6), match='l'>
# ...

# %%
df[~df['match']]
# Out:
#      Unnamed: 0  RALSTHNG  match
# 72    73. edify       NaN  False
# 115  116. idiom       NaN  False
# 120  121. juice       NaN  False
# 121  122. juicy       NaN  False
# 134  135. opium       NaN  False
# 137  138. oxide       NaN  False
# 154  155. quick       NaN  False
# 248  249. voice       NaN  False
